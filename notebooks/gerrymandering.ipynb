# %%
from os import path
import sys
import importlib
sys.path.append(path.abspath('.'))

# %%
import simulated_annealing
import visualisation
import plotting

# %%
DATA_FILE = "./data/data_30_30_rook_adj.json"
OUTPUT_FILE = "./output_sa/output_test_{0}.csv".format("qweaz")
OUTPUT_FILE_1 = "./output_sa/output_test_123456.csv"
IMG_OUTPUT_TEMPLATE = "./visualisation_output_sa/simple_case_3_3_{0}.svg"
JSON_OUTPUT_IMG = "./visualisation_output/{0}.svg".format("simple_case_30_30_json")
# MAX_ITERATIONS = 5000
# MAX_TEMP = 25000
# NUMBER_OF_DISTRICTS = 27


DATA_FILE_3_3 = "./data/data_3_3_rook_picked.json"
OUTPUT_FILE_3_3 = "./output_sa/output_test_3_3_picked.csv"
IMG_OUTPUT_TEMPLATE_3_3 = "./visualisation_output_sa/simple_case_3_3_picked_{0}.svg"
JSON_OUTPUT_IMG_3_3 = "./visualisation_output/{0}.svg".format("simple_case_3_3__picked_json")
# MAX_ITERATIONS = 5000
# MAX_TEMP = 25000
# NUMBER_OF_DISTRICTS = 3

ID_NUMBER = 4
DATA_FILE_6_6 = "./data/region_6_6/region_6_6_data.json"
OUTPUT_FILE_6_6 = "./experiments_output/region_6_6/output_6_6_{0}.csv".format(ID_NUMBER)
IMG_OUTPUT_TEMPLATE_6_6 = "./experiments_output/region_6_6/6_6_region_{0}_iter_{1}.svg".format(ID_NUMBER, "{0}")
JSON_OUTPUT_IMG_6_6 = "./experiments_output/region_6_6/6_6_case_json_img.svg"
PLOT_FILE_6_6 = "./experiments_output/region_6_6/6_6_case_plot_{0}.png".format(ID_NUMBER) 
MAX_ITERATIONS = 5000
MAX_TEMP = 25000
NUMBER_OF_DISTRICTS = 4

# %%
importlib.reload(visualisation)
visualisation.visualise_json_input(DATA_FILE_6_6, JSON_OUTPUT_IMG_6_6)

# %%
# sa = simulated_annealing.SA(DATA_FILE, OUTPUT_FILE, MAX_ITERATIONS, MAX_TEMP, NUMBER_OF_DISTRICTS)
# sa = simulated_annealing.SA(DATA_FILE_3_3, OUTPUT_FILE_3_3, MAX_ITERATIONS, MAX_TEMP, NUMBER_OF_DISTRICTS)
sa = simulated_annealing.SA(DATA_FILE_6_6, OUTPUT_FILE_6_6, MAX_ITERATIONS, MAX_TEMP, NUMBER_OF_DISTRICTS)
sa.run()
# Out:
# Completed

# %%
importlib.reload(visualisation.csv_output_visualiser)
# visualisation.visualise_iterations(OUTPUT_FILE_3_3, DATA_FILE_3_3, IMG_OUTPUT_TEMPLATE_3_3, 5000, 5000)
visualisation.visualise_iterations(OUTPUT_FILE_6_6, DATA_FILE_6_6, IMG_OUTPUT_TEMPLATE_6_6, 4999, 5000)

# %%
plotting.analyse(OUTPUT_FILE_3_3, "example_3_3.png")
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality   cumtime
# 0          0              0                0     0.383027  0.004322
# 1          1              0                0     0.383027  0.009651
# 2          2              0                0     0.383027  0.016963
# 3          3              0                0     0.383027  0.020217
# 4          4              0                0     0.383027  0.023751

# %%
plotting.analyse(OUTPUT_FILE_1, "example_3_3_1.png")
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality   cumtime
# 0          0              0                0     0.505188  0.000710
# 1          1              0                0     0.503974  0.002613
# 2          2              0                0     0.004317  0.004618
# 3          3              0                0     0.004317  0.006124
# 4          4              0                0     0.004317  0.007879

# %%
importlib.reload(plotting)
plotting.analyse(OUTPUT_FILE_6_6, PLOT_FILE_6_6)
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality   cumtime
# 0          0              0                0     0.522917  0.009698
# 1          1              0                0     0.522917  0.070109
# 2          2              0                0     0.522917  0.102790
# 3          3              0                0     0.522917  0.138608
# 4          4              0                0     0.506675  0.174839

# %%
importlib.reload(visualisation)
DATA_FILE_TEST = "./utils/test.json"
JSON_OUTPUT_IMG_TEST = "./utils/test_case.svg"
visualisation.visualise_json_input(DATA_FILE_TEST, JSON_OUTPUT_IMG_TEST)

# %%
# using the cluster
importlib.reload(visualisation.csv_output_visualiser)
# visualisation.visualise_iterations(OUTPUT_FILE_3_3, DATA_FILE_3_3, IMG_OUTPUT_TEMPLATE_3_3, 5000, 5000)
visualisation.visualise_iterations(OUTPUT_FILE_6_6, DATA_FILE_6_6, IMG_OUTPUT_TEMPLATE_6_6, 100000, 100000)

# %%
# using the cluster
importlib.reload(plotting)
plotting.analyse(OUTPUT_FILE_6_6, PLOT_FILE_6_6, "cumtime", "sln_quality", "cumulative time (seconds)", "sln_quality", True)
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality   cumtime  \
# 0          0              0                0     0.526233  0.004429
# 1          1              0                0     0.353010  0.040855
# 2          2              0                0     0.353010  0.075310
# 3          3              0                0     0.353010  0.114977
# 4          4              0                0     0.353010  0.157462
#
#    current_energy  current_temp
# 0        0.526233   100000.0000
# 1        0.353010    99900.0000
# 2        0.455752    99800.1000
# 3        0.508920    99700.2999
# 4        0.509540    99600.5996

# %%
importlib.reload(plotting)
plotting.analyse(OUTPUT_FILE_6_6, PLOT_FILE_6_6, "cumtime", "current_energy", "cumulative time (seconds)", "current_energy")
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality   cumtime  \
# 0          0              0                0     0.526233  0.004429
# 1          1              0                0     0.353010  0.040855
# 2          2              0                0     0.353010  0.075310
# 3          3              0                0     0.353010  0.114977
# 4          4              0                0     0.353010  0.157462
#
#    current_energy  current_temp
# 0        0.526233   100000.0000
# 1        0.353010    99900.0000
# 2        0.455752    99800.1000
# 3        0.508920    99700.2999
# 4        0.509540    99600.5996

# %%
importlib.reload(plotting)
plotting.analyse(OUTPUT_FILE_6_6, PLOT_FILE_6_6, "cumtime", "current_temp", "cumulative time (seconds)", "current_temp")
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality   cumtime  \
# 0          0              0                0     0.526233  0.004429
# 1          1              0                0     0.353010  0.040855
# 2          2              0                0     0.353010  0.075310
# 3          3              0                0     0.353010  0.114977
# 4          4              0                0     0.353010  0.157462
#
#    current_energy  current_temp
# 0        0.526233   100000.0000
# 1        0.353010    99900.0000
# 2        0.455752    99800.1000
# 3        0.508920    99700.2999
# 4        0.509540    99600.5996

# %%
importlib.reload(plotting)
plotting.analyse(OUTPUT_FILE_6_6, PLOT_FILE_6_6, "iteration", "current_temp", "iteration", "current_temp")
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality   cumtime  \
# 0          0              0                0     0.526233  0.004429
# 1          1              0                0     0.353010  0.040855
# 2          2              0                0     0.353010  0.075310
# 3          3              0                0     0.353010  0.114977
# 4          4              0                0     0.353010  0.157462
#
#    current_energy  current_temp
# 0        0.526233   100000.0000
# 1        0.353010    99900.0000
# 2        0.455752    99800.1000
# 3        0.508920    99700.2999
# 4        0.509540    99600.5996

# %%
TEST_ID_NUMBER = 1
REGION_DATA_FILE_PATH_30_30 = "./data/region_30_30/region_30_30_data.json"
OUTPUT_FILE_30_30 = "./experiments_output/region_30_30/v1/output_region_30_30_sa_v1_id{0}.csv".format(TEST_ID_NUMBER)
IMG_OUTPUT_TEMPLATE_30_30 = "./visualisation_output_sa/region_30_30/out_img_region_30_30_sa_v1_id{0}_iter{1}.svg".format(
    TEST_ID_NUMBER, "{0}")
POLITICAL_LANDSCAPE_IMG_30_30 = "./visualisation_output_sa/region_30_30/political_landscape_region_30_30.svg"
PLOT_FILE_30_30 = "./plotting_output/region_30_30/plot_region_30_30_sa_v1_id{0}.png".format(TEST_ID_NUMBER)
importlib.reload(visualisation)
visualisation.visualise_json_input(REGION_DATA_FILE_PATH_30_30, POLITICAL_LANDSCAPE_IMG_30_30, "Political landscape, 30x30 region")

# %%
visualisation.visualise_iterations(OUTPUT_FILE_30_30, REGION_DATA_FILE_PATH_30_30, IMG_OUTPUT_TEMPLATE_30_30, 586, 588)

# %%
importlib.reload(plotting)

plotting.analyse(OUTPUT_FILE_30_30, PLOT_FILE_30_30, "cumtime", "current_temp", "cumulative time (seconds)", "current_temp")
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality    cumtime  \
# 0          0              0                0     0.513847   0.394517
# 1          1              0                0     0.513847  10.084334
# 2          2              0                0     0.513847  23.558693
# 3          3              0                0     0.513847  36.151084
# 4          4              0                0     0.513847  49.785448
#
#    current_energy  current_temp
# 0        0.513847   100000.0000
# 1        0.531627    99900.0000
# 2        0.522787    99800.1000
# 3        0.515390    99700.2999
# 4        0.520713    99600.5996

# %%
plotting.analyse(OUTPUT_FILE_30_30, PLOT_FILE_30_30, "cumtime", "sln_quality", "cumulative time (seconds)", "Soltuon quality", True)
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality    cumtime  \
# 0          0              0                0     0.513847   0.394517
# 1          1              0                0     0.513847  10.084334
# 2          2              0                0     0.513847  23.558693
# 3          3              0                0     0.513847  36.151084
# 4          4              0                0     0.513847  49.785448
#
#    current_energy  current_temp
# 0        0.513847   100000.0000
# 1        0.531627    99900.0000
# 2        0.522787    99800.1000
# 3        0.515390    99700.2999
# 4        0.520713    99600.5996

# %%
plotting.analyse(OUTPUT_FILE_30_30, PLOT_FILE_30_30, "iteration", "current_energy", "iteration", "current_energy")
# Out:
#    iteration  fitness_value  unfitness_value  sln_quality    cumtime  \
# 0          0              0                0     0.513847   0.394517
# 1          1              0                0     0.513847  10.084334
# 2          2              0                0     0.513847  23.558693
# 3          3              0                0     0.513847  36.151084
# 4          4              0                0     0.513847  49.785448
#
#    current_energy  current_temp
# 0        0.513847   100000.0000
# 1        0.531627    99900.0000
# 2        0.522787    99800.1000
# 3        0.515390    99700.2999
# 4        0.520713    99600.5996

# %%
TEST_ID_NUMBER = 1
# OPTIMAL_SLN_FILE_PATH_18_18 = "./data/region_18_18/region_18_18_opt_sln.json"
# POLITICAL_LANDSCAPE_IMG_18_18 = "./visualisation_output_sa/region_18_18/political_landscape_region_18_18.svg"

REGION_DATA_FILE_PATH_18_18 = "./data/region_18_18/region_18_18_data.json"
title_18_18 = "Region 18x18"
img_path_18_18 = "./visualisation_output_sa/region_18_18/region_18_18_opt_sln_vis.svg"
IMG_OUTPUT_TEMPLATE_18_18 = "./visualisation_output_sa/region_18_18/out_img_region_18_18_sa_v1_id{0}_iter{1}.png".format(
    TEST_ID_NUMBER, "{0}")
OUTPUT_FILE_18_18 = "./experiments_output/region_18_18/output_region_18_18_sa_v1_id1.csv"
PLOT_FILE_18_18 = "./plotting_output/region_18_18/plot_{1}_region_18_18_sa_v1_id{0}.png".format(TEST_ID_NUMBER, "{0}")

# visualize_iteration(OPTIMAL_SLN_FILE_PATH_18_18, REGION_DATA_FILE_PATH_18_18, title_18_18, img_path_18_18)

# %%
visualisation.visualise_iterations(OUTPUT_FILE_18_18, REGION_DATA_FILE_PATH_18_18, IMG_OUTPUT_TEMPLATE_18_18, 5000, 5000)

# %%
plotting.analyse(OUTPUT_FILE_18_18, PLOT_FILE_18_18.format("energy"), "iteration", "current_energy", "iteration", "current_energy")

# %%
TEST_ID_NUMBER = 1
# OPTIMAL_SLN_FILE_PATH_18_18 = "./data/region_18_18/region_18_18_opt_sln.json"
# POLITICAL_LANDSCAPE_IMG_18_18 = "./visualisation_output_sa/region_18_18/political_landscape_region_18_18.svg"

REGION_DATA_FILE_PATH_24_24 = "./data/region_24_24/region_24_24_data.json"
title_24_24 = "Region 24x24"
img_path_24_24 = "./visualisation_output_sa/region_24_24/region_24_24_opt_sln_vis.svg"
IMG_OUTPUT_TEMPLATE_24_24 = "./visualisation_output_sa/region_24_24/out_img_region_24_24_sa_v1_id{0}_iter{1}.png".format(
    TEST_ID_NUMBER, "{0}")
OUTPUT_FILE_24_24= "./experiments_output/region_24_24/output_region_24_24_sa_v1_id1.csv"
PLOT_FILE_24_24 = "./plotting_output/region_24_24/plot_{1}_region_24_24_sa_v1_id{0}.png".format(TEST_ID_NUMBER, "{0}")

# %%
visualisation.visualise_iterations(OUTPUT_FILE_24_24, REGION_DATA_FILE_PATH_24_24, IMG_OUTPUT_TEMPLATE_24_24, 5000, 5000)

# %%
plotting.analyse(OUTPUT_FILE_24_24, PLOT_FILE_24_24.format("energy"), "iteration", "current_energy", "iteration", "current_energy")
# Out:
#    iteration  unfitness_value  fitness_value  sln_quality    cumtime  \
# 0          0              0.5       0.004425     0.504425   0.168228
# 1          1              0.5       0.023829     0.504425   3.695341
# 2          2              0.5       0.028517     0.504425   9.064289
# 3          3              0.5       0.010897     0.504425  15.121347
# 4          4              0.5       0.011461     0.504425  20.479201
#
#    current_energy  current_temp
# 0        0.504425  10000.000000
# 1        0.523829   9967.000000
# 2        0.528517   9934.108900
# 3        0.510898   9901.326341
# 4        0.511461   9868.651964

# %%
plotting.analyse(OUTPUT_FILE_24_24, PLOT_FILE_24_24.format("time"), "iteration", "cumtime", "iteration","cumtime")
# Out:
#    iteration  unfitness_value  fitness_value  sln_quality    cumtime  \
# 0          0              0.5       0.004425     0.504425   0.168228
# 1          1              0.5       0.023829     0.504425   3.695341
# 2          2              0.5       0.028517     0.504425   9.064289
# 3          3              0.5       0.010897     0.504425  15.121347
# 4          4              0.5       0.011461     0.504425  20.479201
#
#    current_energy  current_temp
# 0        0.504425  10000.000000
# 1        0.523829   9967.000000
# 2        0.528517   9934.108900
# 3        0.510898   9901.326341
# 4        0.511461   9868.651964

# %%
TEST_ID_NUMBER = 1
# OPTIMAL_SLN_FILE_PATH_18_18 = "./data/region_18_18/region_18_18_opt_sln.json"
# POLITICAL_LANDSCAPE_IMG_18_18 = "./visualisation_output_sa/region_18_18/political_landscape_region_18_18.svg"

REGION_DATA_FILE_PATH_30_30 = "./data/region_30_30/region_30_30_data.json"
title_30_30 = "Region 30x30"
img_path_30_30 = "./visualisation_output_sa/region_30_30/region_30_30_opt_sln_vis.svg"
IMG_OUTPUT_TEMPLATE_30_30 = "./visualisation_output_sa/region_30_30/out_img_region_30_30_sa_v1_id{0}_iter{1}.png".format(
    TEST_ID_NUMBER, "{0}")
OUTPUT_FILE_30_30= "./experiments_output/region_30_30/output_region_30_30_sa_v1_id1.csv"
PLOT_FILE_30_30 = "./plotting_output/region_30_30/plot_{1}_region_30_30_sa_v1_id{0}.png".format(TEST_ID_NUMBER, "{0}")

# %%
plotting.analyse(OUTPUT_FILE_30_30, PLOT_FILE_30_30.format("time"), "iteration", "cumtime", "iteration","cumtime")
# Out:
#    iteration  unfitness_value  fitness_value  sln_quality    cumtime  \
# 0          0              0.5       0.015455     0.515455   0.376102
# 1          1              0.5       0.017938     0.515455   8.293027
# 2          2              0.5       0.030844     0.515455  18.053259
# 3          3              0.5       0.022433     0.515455  29.868396
# 4          4              0.5       0.026302     0.515455  42.318047
#
#    current_energy  current_temp
# 0        0.515455  10000.000000
# 1        0.517938   9967.000000
# 2        0.530844   9934.108900
# 3        0.522433   9901.326341
# 4        0.526302   9868.651964
# <img src="data:image/png;base64,..." width="1000">

# %%
plotting.analyse(OUTPUT_FILE_30_30, PLOT_FILE_30_30.format("energy"), "iteration", "current_energy", "iteration", "current_energy")
# Out:
#    iteration  unfitness_value  fitness_value  sln_quality    cumtime  \
# 0          0              0.5       0.015455     0.515455   0.376102
# 1          1              0.5       0.017938     0.515455   8.293027
# 2          2              0.5       0.030844     0.515455  18.053259
# 3          3              0.5       0.022433     0.515455  29.868396
# 4          4              0.5       0.026302     0.515455  42.318047
#
#    current_energy  current_temp
# 0        0.515455  10000.000000
# 1        0.517938   9967.000000
# 2        0.530844   9934.108900
# 3        0.522433   9901.326341
# 4        0.526302   9868.651964
# <img src="data:image/png;base64,..." width="1000">

# %%
importlib.reload(visualisation)
visualisation.visualise_iterations(OUTPUT_FILE_30_30, REGION_DATA_FILE_PATH_30_30, IMG_OUTPUT_TEMPLATE_30_30, 5000, 5000, title_30_30)
